# %%
# !pip install pgmpy
# Out:
# Collecting pgmpy
#   Downloading pgmpy-0.1.25-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels in c:\users\vikra\anaconda3\lib\site-packages (from pgmpy) (0.13.2)
# Requirement already satisfied: tqdm in c:\users\vikra\anaconda3\lib\site-packages (from pgmpy) (4.64.1)
# Requirement already satisfied: numpy in c:\users\vikra\appdata\roaming\python\python39\site-packages (from pgmpy) (1.24.3)
# Requirement already satisfied: joblib in c:\users\vikra\anaconda3\lib\site-packages (from pgmpy) (1.1.0)
# Requirement already satisfied: scikit-learn in c:\users\vikra\anaconda3\lib\site-packages (from pgmpy) (1.0.2)
# Requirement already satisfied: pandas in c:\users\vikra\anaconda3\lib\site-packages (from pgmpy) (1.4.4)
# Requirement already satisfied: networkx in c:\users\vikra\anaconda3\lib\site-packages (from pgmpy) (2.8.4)
# Requirement already satisfied: pyparsing in c:\users\vikra\anaconda3\lib\site-packages (from pgmpy) (3.0.9)
# Requirement already satisfied: opt-einsum in c:\users\vikra\appdata\roaming\python\python39\site-packages (from pgmpy) (3.3.0)
# Requirement already satisfied: torch in c:\users\vikra\appdata\roaming\python\python39\site-packages (from pgmpy) (2.2.0)
# Requirement already satisfied: scipy in c:\users\vikra\anaconda3\lib\site-packages (from pgmpy) (1.9.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vikra\anaconda3\lib\site-packages (from pandas->pgmpy) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\vikra\anaconda3\lib\site-packages (from pandas->pgmpy) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vikra\anaconda3\lib\site-packages (from scikit-learn->pgmpy) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\vikra\anaconda3\lib\site-packages (from statsmodels->pgmpy) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\vikra\appdata\roaming\python\python39\site-packages (from statsmodels->pgmpy) (23.2)
# Requirement already satisfied: filelock in c:\users\vikra\anaconda3\lib\site-packages (from torch->pgmpy) (3.6.0)
# Requirement already satisfied: fsspec in c:\users\vikra\anaconda3\lib\site-packages (from torch->pgmpy) (2022.7.1)
# Requirement already satisfied: sympy in c:\users\vikra\anaconda3\lib\site-packages (from torch->pgmpy) (1.10.1)
# Requirement already satisfied: jinja2 in c:\users\vikra\anaconda3\lib\site-packages (from torch->pgmpy) (2.11.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\vikra\appdata\roaming\python\python39\site-packages (from torch->pgmpy) (4.9.0)
# Requirement already satisfied: colorama in c:\users\vikra\anaconda3\lib\site-packages (from tqdm->pgmpy) (0.4.5)
# Requirement already satisfied: six in c:\users\vikra\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels->pgmpy) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\vikra\anaconda3\lib\site-packages (from jinja2->torch->pgmpy) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\vikra\anaconda3\lib\site-packages (from sympy->torch->pgmpy) (1.2.1)
# Installing collected packages: pgmpy
# Successfully installed pgmpy-0.1.25

# %%
import numpy as np
import pandas as pd
from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.models import BayesianNetwork
from pgmpy.inference import VariableElimination

# Load and preprocess data
heartDisease = pd.read_csv('heart.csv').replace('?', np.nan)
print('Sample instances from the dataset:\n', heartDisease.head())
print('\nAttributes and datatypes:\n', heartDisease.dtypes)

# Define and fit Bayesian Network model
model = BayesianNetwork([('age', 'heartdisease'), ('sex', 'heartdisease'), 
                         ('exang', 'heartdisease'), ('cp', 'heartdisease'), 
                         ('heartdisease', 'restecg'), ('heartdisease', 'chol')])
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)

# Inferencing with Bayesian Network
infer = VariableElimination(model)
print('\n1. Probability of HeartDisease given evidence= restecg')
print(infer.query(variables=['heartdisease'], evidence={'restecg': 1}))

print('\n2. Probability of HeartDisease given evidence= cp')
print(infer.query(variables=['heartdisease'], evidence={'cp': 2}))
# Out:
# Sample instances from the dataset:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#   ca thal  heartdisease
# 0  0    6             0
# 1  3    3             2
# 2  2    7             1
# 3  0    3             0
# 4  0    3             0
#
# Attributes and datatypes:
#  age               int64
# sex               int64
# cp                int64
# trestbps          int64
# chol              int64
# fbs               int64
# restecg           int64
# thalach           int64
# exang             int64
# oldpeak         float64
# slope             int64
# ca               object
# thal             object
# heartdisease      int64
# dtype: object
#
# 1. Probability of HeartDisease given evidence= restecg
# +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              0.1016 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.0000 |
# +-----------------+---------------------+
# | heartdisease(2) |              0.2361 |
# +-----------------+---------------------+
# | heartdisease(3) |              0.2017 |
# +-----------------+---------------------+
# | heartdisease(4) |              0.4605 |
# +-----------------+---------------------+
#
# 2. Probability of HeartDisease given evidence= cp
# +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              0.3742 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.2018 |
# +-----------------+---------------------+
# | heartdisease(2) |              0.1375 |
# +-----------------+---------------------+
# | heartdisease(3) |              0.1541 |
# +-----------------+---------------------+
# | heartdisease(4) |              0.1323 |
# +-----------------+---------------------+

# %%
import numpy as np
import pandas as pd
from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.models import BayesianNetwork
from pgmpy.inference import VariableElimination

# Load and preprocess data
data = pd.read_csv('heart.csv')
print('Sample data:\n', data.head())
print('\nData types:\n', data.dtypes)+

# Define and fit Bayesian Network model
model = BayesianNetwork([('age', 'heartdisease'), ('sex', 'heartdisease'), 
                         ('exang', 'heartdisease'), ('cp', 'heartdisease'), 
                         ('heartdisease', 'restecg'), ('heartdisease', 'chol')])
model.fit(data, estimator=MaximumLikelihoodEstimator)

# Inference
infer = VariableElimination(model)
print('\nProbability of HeartDisease given restecg=1:\n', infer.query(variables=['heartdisease'], evidence={'restecg': 1}))
print('\nProbability of HeartDisease given cp=2:\n', infer.query(variables=['heartdisease'], evidence={'cp': 2}))
# Out:
# Sample data:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#   ca thal  heartdisease
# 0  0    6             0
# 1  3    3             2
# 2  2    7             1
# 3  0    3             0
# 4  0    3             0
#
# Data types:
#  age               int64
# sex               int64
# cp                int64
# trestbps          int64
# chol              int64
# fbs               int64
# restecg           int64
# thalach           int64
# exang             int64
# oldpeak         float64
# slope             int64
# ca               object
# thal             object
# heartdisease      int64
# dtype: object
#
# Probability of HeartDisease given restecg=1:
#  +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              0.1016 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.0000 |
# +-----------------+---------------------+
# | heartdisease(2) |              0.2361 |
# +-----------------+---------------------+
# | heartdisease(3) |              0.2017 |
# +-----------------+---------------------+
# | heartdisease(4) |              0.4605 |
# +-----------------+---------------------+
#
# Probability of HeartDisease given cp=2:
#  +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              0.3742 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.2018 |
# +-----------------+---------------------+
# | heartdisease(2) |              0.1375 |
# +-----------------+---------------------+
# | heartdisease(3) |              0.1541 |
# +-----------------+---------------------+
# | heartdisease(4) |              0.1323 |
# +-----------------+---------------------+

# %%
import numpy as np
import pandas as pd

# %%
# !pip install pgmpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pgmpy in c:\users\vikra\appdata\roaming\python\python39\site-packages (0.1.25)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from pgmpy) (1.1.0)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from pgmpy) (1.4.4)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from pgmpy) (1.9.1)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from pgmpy) (2.8.4)
# Requirement already satisfied: numpy in c:\users\vikra\appdata\roaming\python\python39\site-packages (from pgmpy) (1.24.3)
# Requirement already satisfied: pyparsing in c:\programdata\anaconda3\lib\site-packages (from pgmpy) (3.0.9)
# Requirement already satisfied: statsmodels in c:\programdata\anaconda3\lib\site-packages (from pgmpy) (0.13.2)
# Requirement already satisfied: opt-einsum in c:\users\vikra\appdata\roaming\python\python39\site-packages (from pgmpy) (3.3.0)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from pgmpy) (1.0.2)
# Requirement already satisfied: torch in c:\users\vikra\appdata\roaming\python\python39\site-packages (from pgmpy) (2.2.0)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from pgmpy) (4.64.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->pgmpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->pgmpy) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->pgmpy) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\programdata\anaconda3\lib\site-packages (from statsmodels->pgmpy) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\vikra\appdata\roaming\python\python39\site-packages (from statsmodels->pgmpy) (23.2)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch->pgmpy) (2.11.3)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from torch->pgmpy) (2022.7.1)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from torch->pgmpy) (3.6.0)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from torch->pgmpy) (1.10.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\vikra\appdata\roaming\python\python39\site-packages (from torch->pgmpy) (4.9.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->pgmpy) (0.4.5)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels->pgmpy) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch->pgmpy) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->torch->pgmpy) (1.2.1)

# %%
from pgmpy.estimators import MaximumLikelihoodEstimator

# %%
from pgmpy.models import BayesianNetwork

# %%
from pgmpy.inference import VariableElimination

# %%
data = pd.read_csv('heart.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#   ca thal  heartdisease
# 0  0    6             0
# 1  3    3             2
# 2  2    7             1
# 3  0    3             0
# 4  0    3             0

# %%
print(data.dtypes)
# Out:
# age               int64
# sex               int64
# cp                int64
# trestbps          int64
# chol              int64
# fbs               int64
# restecg           int64
# thalach           int64
# exang             int64
# oldpeak         float64
# slope             int64
# ca               object
# thal             object
# heartdisease      int64
# dtype: object

# %%
mode = BayesianNetwork([('age', 'heartdisease'), ('sex', 'heartdisease'), 
                         ('exang', 'heartdisease'), ('cp', 'heartdisease'), 
                         ('heartdisease', 'restecg'), ('heartdisease', 'chol')])

# %%
import numpy as np
import pandas as pd
from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.models import BayesianNetwork
from pgmpy.inference import VariableElimination

# %%
data = pd.read_csv('heart.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#   ca thal  heartdisease
# 0  0    6             0
# 1  3    3             2
# 2  2    7             1
# 3  0    3             0
# 4  0    3             0

# %%
model = BayesianNetwork([('age','heartdisease'),('sex','heartdisease'),('exang','heartdisease'),('cp','heartdisease'),('heartdisease','restecg'),('heartdisease','chol')])

# %%
model.fit(data,estimator=MaximumLikelihoodEstimator)

# %%
infer = VariableElimination(model)

# %%
print("restecg=1",infer.query(variables=['heartdisease'],evidence={'restecg':1}))
print("cp=2",infer.query(variables=['heartdisease'],evidence={'cp':2}))
# Out:
# restecg=1 +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              0.1016 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.0000 |
# +-----------------+---------------------+
# | heartdisease(2) |              0.2361 |
# +-----------------+---------------------+
# | heartdisease(3) |              0.2017 |
# +-----------------+---------------------+
# | heartdisease(4) |              0.4605 |
# +-----------------+---------------------+
# cp=2 +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              0.3742 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.2018 |
# +-----------------+---------------------+
# | heartdisease(2) |              0.1375 |
# +-----------------+---------------------+
# | heartdisease(3) |              0.1541 |
# +-----------------+---------------------+
# | heartdisease(4) |              0.1323 |
# +-----------------+---------------------+
